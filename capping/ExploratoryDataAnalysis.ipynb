# %%
unlabeled = pd.read_csv('https://raw.githubusercontent.com/NicholasMaisel/Capping/main/capping/datasets/unlabeled_data/unlabled_features.csv?token=ALHQJDQ46E2XCSYZCNDGGALAXDXKQ')
unlabeled
# Out:
#       acousticness  ...                                        name
# 0           0.1050  ...                                Unbelievable
# 1           0.2750  ...               Havin My Way (feat. Lil Durk)
# 2           0.1490  ...                                 Unbelievers
# 3           0.2300  ...                     Give Your Heart a Break
# 4           0.0236  ...                                        Riot
# ...            ...  ...                                         ...
# 9987        0.2770  ...                                  Next To Me
# 9988        0.9860  ...  Nun freut euch, Gottes Kinder all, BWV 387
# 9989        0.0428  ...                           Whatever It Takes
# 9990        0.1710  ...      Nun, komm' der Heiden Heiland, BWV 599
# 9991        0.0174  ...                                    Stitches
#
# [9992 rows x 17 columns]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
import sklearn as skl

# %%
labeled = pd.read_csv('https://raw.githubusercontent.com/NicholasMaisel/Capping/main/capping/datasets/labeled_data/labeled_features.csv?token=ALHQJDTI3LONW345ZTL75D3AXDXHC')
labeled
# Out:
#       acousticness  ...                                               name
# 0         0.171000  ...                               Jump - 2015 Remaster
# 1         0.000894  ...                                More Than a Feeling
# 2         0.448000  ...                                      American Girl
# 3         0.181000  ...                                 Sweet Home Alabama
# 4         0.365000  ...                                          The Joker
# ...            ...  ...                                                ...
# 5574      0.995000  ...  10 Préludes Op. 23: No. 10 in G-Flat Major - Live
# 5575      0.928000  ...  Scheherezade Op. 35: I. The Sea and Sinbad's Ship
# 5576      0.929000  ...                                  Presto in C Major
# 5577      0.994000  ...                            Sonata in D Minor K. 32
# 5578      0.840000  ...  Zwei geistliche Lieder für eine mittlere Sings...
#
# [5579 rows x 18 columns]

# %%
labeled.shape
# Out:
# (5579, 18)

# %%
unlabeled.shape
# Out:
# (9992, 17)

# %%
unlabeled.isnull().sum()
# Out:
# acousticness        0
# danceability        0
# duration_ms         0
# energy              0
# id                  0
# instrumentalness    0
# key                 0
# liveness            0
# loudness            0
# mode                0
# speechiness         0
# tempo               0
# time_signature      0
# valence             0
# arstist_id          0
# artist_name         0
# name                0
# dtype: int64

# %%
labeled.isnull().sum()
# Out:
# acousticness        0
# danceability        0
# duration_ms         0
# energy              0
# id                  0
# instrumentalness    0
# key                 0
# liveness            0
# loudness            0
# mode                0
# speechiness         0
# tempo               0
# time_signature      0
# valence             0
# artist_id           0
# artist_name         0
# genre               0
# name                0
# dtype: int64

# %%
unlabeled.dtypes
# Out:
# acousticness        float64
# danceability        float64
# duration_ms         float64
# energy              float64
# id                   object
# instrumentalness    float64
# key                 float64
# liveness            float64
# loudness            float64
# mode                float64
# speechiness         float64
# tempo               float64
# time_signature      float64
# valence             float64
# arstist_id           object
# artist_name          object
# name                 object
# dtype: object

# %%
labeled.dtypes
# Out:
# acousticness        float64
# danceability        float64
# duration_ms         float64
# energy              float64
# id                   object
# instrumentalness    float64
# key                 float64
# liveness            float64
# loudness            float64
# mode                float64
# speechiness         float64
# tempo               float64
# time_signature      float64
# valence             float64
# artist_id            object
# artist_name          object
# genre                object
# name                 object
# dtype: object

# %%
duplicate_rows_unlabeled = unlabeled[unlabeled.duplicated()]
print("number of duplicate rows: ", duplicate_rows_unlabeled.shape)
# Out:
# number of duplicate rows:  (0, 17)

# %%
duplicate_rows_labeled = labeled[labeled.duplicated()]
print("number of duplicate rows: ", duplicate_rows_labeled.shape)
# Out:
# number of duplicate rows:  (0, 18)

# %%
unlabeled.count
labeled.count
# Out:
# <bound method DataFrame.count of       acousticness  ...                                               name
# 0         0.171000  ...                               Jump - 2015 Remaster
# 1         0.000894  ...                                More Than a Feeling
# 2         0.448000  ...                                      American Girl
# 3         0.181000  ...                                 Sweet Home Alabama
# 4         0.365000  ...                                          The Joker
# ...            ...  ...                                                ...
# 5574      0.995000  ...  10 Préludes Op. 23: No. 10 in G-Flat Major - Live
# 5575      0.928000  ...  Scheherezade Op. 35: I. The Sea and Sinbad's Ship
# 5576      0.929000  ...                                  Presto in C Major
# 5577      0.994000  ...                            Sonata in D Minor K. 32
# 5578      0.840000  ...  Zwei geistliche Lieder für eine mittlere Sings...
#
# [5579 rows x 18 columns]>

# %%
unlabeled= unlabeled.drop_duplicates()
unlabeled.head(5)
# Out:
#    acousticness  danceability  ...      artist_name                           name
# 0        0.1050         0.532  ...     Why Don't We                   Unbelievable
# 1        0.2750         0.802  ...        Lil Skies  Havin My Way (feat. Lil Durk)
# 2        0.1490         0.644  ...  Vampire Weekend                    Unbelievers
# 3        0.2300         0.651  ...      Demi Lovato        Give Your Heart a Break
# 4        0.0236         0.853  ...        Lil Skies                           Riot
#
# [5 rows x 17 columns]

# %%
labeled= labeled.drop_duplicates()
labeled.head(5)
# Out:
#    acousticness  danceability  ...  genre                  name
# 0      0.171000         0.572  ...   Rock  Jump - 2015 Remaster
# 1      0.000894         0.377  ...   Rock   More Than a Feeling
# 2      0.448000         0.550  ...   Rock         American Girl
# 3      0.181000         0.596  ...   Rock    Sweet Home Alabama
# 4      0.365000         0.596  ...   Rock             The Joker
#
# [5 rows x 18 columns]

# %%
sns.boxplot(x=unlabeled['valence'])

# %%
sns.boxplot(x=labeled['valence'])

# %%
sns.boxplot(x=unlabeled['tempo'])

# %%
sns.boxplot(x=labeled['tempo'])

# %%
sns.boxplot(x=unlabeled['speechiness'])

# %%
sns.boxplot(x=labeled['speechiness'])

# %%
plt.figure(figsize=(20,10))
c= unlabeled.corr()
sns.heatmap(c,cmap="BrBG",annot=True)
c
# Out:
#                   acousticness  danceability  ...  time_signature   valence
# acousticness          1.000000     -0.304513  ...       -0.140872 -0.182554
# danceability         -0.304513      1.000000  ...        0.222293  0.434431
# duration_ms          -0.053046     -0.155290  ...        0.021023 -0.083074
# energy               -0.636510      0.207156  ...        0.160375  0.370004
# instrumentalness      0.277615     -0.300160  ...       -0.080791 -0.278537
# key                  -0.028753      0.033526  ...        0.005601  0.048243
# liveness             -0.063366     -0.109336  ...       -0.016679  0.026262
# loudness             -0.551711      0.367413  ...        0.184811  0.334735
# mode                  0.041600     -0.068997  ...       -0.007731 -0.029013
# speechiness          -0.086679      0.275149  ...        0.058551  0.109497
# tempo                -0.200041      0.051057  ...        0.096054  0.089046
# ...

# %% [markdown]
# From this we can se that loudness and energy are strongly positively correlated. Energy and acousticness, loudness and acousticness, and loudness and instrumentals are strongly negatively correlated.

# %%
sns.scatterplot(unlabeled['acousticness'], unlabeled['energy'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.scatterplot(unlabeled['acousticness'], unlabeled['loudness'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.scatterplot(unlabeled['instrumentalness'], unlabeled['loudness'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.scatterplot(unlabeled['loudness'], unlabeled['energy'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.figure(figsize=(20,10))
c= labeled.corr()
sns.heatmap(c,cmap="BrBG",annot=True)
c
# Out:
#                   acousticness  danceability  ...  time_signature   valence
# acousticness          1.000000     -0.445451  ...       -0.245057 -0.362853
# danceability         -0.445451      1.000000  ...        0.241209  0.511068
# duration_ms           0.331178     -0.342180  ...       -0.082432 -0.249246
# energy               -0.815267      0.378020  ...        0.254257  0.437108
# instrumentalness      0.491887     -0.391408  ...       -0.184595 -0.367417
# key                  -0.038241      0.032084  ...       -0.005607  0.039896
# liveness             -0.144101      0.028296  ...        0.044001  0.085564
# loudness             -0.729848      0.480230  ...        0.247241  0.369643
# mode                  0.049918     -0.076887  ...       -0.016461 -0.012877
# speechiness          -0.223710      0.342792  ...        0.102824  0.197418
# tempo                -0.229664     -0.047504  ...        0.025893  0.086626
# ...

# %% [markdown]
# Like the unlabeled data, the labeled data's loudness and energy are strongly positively correlated. Energy and acousticness, loudness and acousticness, and loudness and instrumentals are strongly negatively correlated.

# %%
sns.scatterplot(labeled['acousticness'], labeled['energy'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.scatterplot(labeled['acousticness'], labeled['loudness'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.scatterplot(labeled['instrumentalness'], labeled['loudness'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.scatterplot(labeled['loudness'], labeled['energy'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
